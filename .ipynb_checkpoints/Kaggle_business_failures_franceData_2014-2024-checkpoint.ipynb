# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df = pd.read_csv("/Users/sandeepsrinivasdwaram/Documents/business_failures/business_failures_franceData_2014-2024.csv")

# %%
df
# Out:
#      YearQuarterId YearGroupId        Year Quarter  FailureUnit  Zone  \
# 0          2018-Q1       G2018  01/01/2018      Q1           26     1
# 1          2018-Q1       G2018  01/01/2018      Q1           44     2
# 2          2018-Q1       G2018  01/01/2018      Q1           87     3
# 3          2018-Q1       G2018  01/01/2018      Q1          116     3
# 4          2018-Q1       G2018  01/01/2018      Q1           84     2
# ...            ...         ...         ...     ...          ...   ...
# 5055       2017-Q4       G2017  01/10/2017      Q4          110     3
# 5056       2017-Q4       G2017  01/10/2017      Q4        14159     4
# 5057       2017-Q4       G2017  01/10/2017      Q4            9     1
# 5058       2017-Q4       G2017  01/10/2017      Q4          186     4
# 5059       2017-Q4       G2017  01/10/2017      Q4          451     4
#
#      ZoneCategory          Location      Capital                   Region  \
# 0             Low            Ariège         Foix                Occitanie
# 1          Medium              Cher      Bourges        Centre-ValdeLoire
# 2            High     Côtes-d'Armor  SaintBrieuc                 Bretagne
# 3            High          Dordogne  \tPérigueux       Nouvelle-Aquitaine
# 4          Medium             Doubs   \tBesançon  Bourgogne-Franche-Comté
# ...           ...               ...          ...                      ...
# 5055         High        Guadeloupe  Basse-Terre                      Nil
# 5056     VeryHigh            France        Paris                      Nil
# 5057          Low  FrenchTeritories          Nil                      Nil
# 5058     VeryHigh         LaRéunion  Saint-Denis                      Nil
# 5059     VeryHigh          Overseas          Nil                      Nil
#
#       Direction LocationCategory  CalandarYear
# 0         South                D          2018
# 1       Central                D          2018
# 2     NorthWest                D          2018
# 3     SouthWest                D          2018
# 4          East                D          2018
# ...         ...              ...           ...
# 5055        Nil                C          2017
# 5056        Nil                C          2017
# 5057        Nil             OFOT          2017
# 5058        Nil                C          2017
# 5059        Nil                O          2017
#
# [5060 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['YearQuarterId', 'YearGroupId', 'Year', 'Quarter', 'FailureUnit',
#        'Zone', 'ZoneCategory', 'Location', 'Capital', 'Region', 'Direction',
#        'LocationCategory', 'CalandarYear'],
#       dtype='object')

# %%
df.dtypes
# Out:
# YearQuarterId       object
# YearGroupId         object
# Year                object
# Quarter             object
# FailureUnit          int64
# Zone                 int64
# ZoneCategory        object
# Location            object
# Capital             object
# Region              object
# Direction           object
# LocationCategory    object
# CalandarYear         int64
# dtype: object

# %%
df['Year'] = pd.to_datetime(df['Year'])

# %%
df.head(10)
# Out:
#   YearQuarterId YearGroupId       Year Quarter  FailureUnit  Zone  \
# 0       2018-Q1       G2018 2018-01-01      Q1           26     1
# 1       2018-Q1       G2018 2018-01-01      Q1           44     2
# 2       2018-Q1       G2018 2018-01-01      Q1           87     3
# 3       2018-Q1       G2018 2018-01-01      Q1          116     3
# 4       2018-Q1       G2018 2018-01-01      Q1           84     2
# 5       2018-Q1       G2018 2018-01-01      Q1          122     3
# 6       2018-Q1       G2018 2018-01-01      Q1           44     2
# 7       2018-Q1       G2018 2018-01-01      Q1           46     2
# 8       2018-Q1       G2018 2018-01-01      Q1           43     2
# 9       2018-Q1       G2018 2018-01-01      Q1          319     4
#
#   ZoneCategory         Location      Capital                   Region  \
# 0          Low           Ariège         Foix                Occitanie
# 1       Medium             Cher      Bourges        Centre-ValdeLoire
# 2         High    Côtes-d'Armor  SaintBrieuc                 Bretagne
# 3         High         Dordogne  \tPérigueux       Nouvelle-Aquitaine
# 4       Medium            Doubs   \tBesançon  Bourgogne-Franche-Comté
# 5         High            Drôme      Valence  Bourgogne-Franche-Comté
# 6       Medium             Gers       \tAuch                Occitanie
# 7       Medium      Haute-Corse     \tBastia                    Corse
# 8       Medium  Hautes-Pyrénées       Tarbes                Occitanie
# 9     VeryHigh   Hauts-de-Seine     Nanterre            Île-de-France
#
#       Direction LocationCategory  CalandarYear
# 0         South                D          2018
# 1       Central                D          2018
# 2     NorthWest                D          2018
# 3     SouthWest                D          2018
# 4          East                D          2018
# 5          East                D          2018
# 6         South                D          2018
# 7         South                D          2018
# 8         South                D          2018
# 9  NorthCentral                D          2018

# %%
df.dtypes
# Out:
# YearQuarterId               object
# YearGroupId                 object
# Year                datetime64[ns]
# Quarter                     object
# FailureUnit                  int64
# Zone                         int64
# ZoneCategory                object
# Location                    object
# Capital                     object
# Region                      object
# Direction                   object
# LocationCategory            object
# CalandarYear                 int64
# dtype: object

# %% [markdown]
# Data Understanding and Summary Stats:

# %% [markdown]
# Summary Stats:

# %%
df.shape
# Out:
# (5060, 13)

# %%
df.columns
# Out:
# Index(['YearQuarterId', 'YearGroupId', 'Year', 'Quarter', 'FailureUnit',
#        'Zone', 'ZoneCategory', 'Location', 'Capital', 'Region', 'Direction',
#        'LocationCategory', 'CalandarYear'],
#       dtype='object')

# %%
df.dtypes
# Out:
# YearQuarterId               object
# YearGroupId                 object
# Year                datetime64[ns]
# Quarter                     object
# FailureUnit                  int64
# Zone                         int64
# ZoneCategory                object
# Location                    object
# Capital                     object
# Region                      object
# Direction                   object
# LocationCategory            object
# CalandarYear                 int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5060 entries, 0 to 5059
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   YearQuarterId     5060 non-null   object
#  1   YearGroupId       5060 non-null   object
#  2   Year              5060 non-null   datetime64[ns]
#  3   Quarter           5060 non-null   object
#  4   FailureUnit       5060 non-null   int64
#  5   Zone              5060 non-null   int64
#  6   ZoneCategory      5060 non-null   object
#  7   Location          5060 non-null   object
#  8   Capital           5060 non-null   object
#  9   Region            5060 non-null   object
#  10  Direction         5060 non-null   object
#  11  LocationCategory  5060 non-null   object
#  12  CalandarYear      5060 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(9)
# memory usage: 514.0+ KB

# %%
df.describe()
# Out:
#                                 Year   FailureUnit         Zone  CalandarYear
# count                           5060   5060.000000  5060.000000   5060.000000
# mean   2019-01-04 20:51:36.284584960    323.962451     2.484783   2018.998024
# min              2014-01-01 00:00:00      0.000000     1.000000   2014.000000
# 25%              2016-01-07 00:00:00     45.000000     1.000000   2016.000000
# 50%              2019-01-04 00:00:00     97.000000     2.000000   2019.000000
# 75%              2022-01-01 00:00:00    221.000000     3.000000   2022.000000
# max              2024-01-10 00:00:00  18612.000000     4.000000   2024.000000
# std                              NaN   1248.369443     1.120160      3.162590

# %%
df.describe(include='all')
# Out:
#        YearQuarterId YearGroupId                           Year Quarter  \
# count           5060        5060                           5060    5060
# unique            44          11                            NaN       4
# top          2018-Q1       G2018                            NaN      Q1
# freq             115         460                            NaN    1265
# mean             NaN         NaN  2019-01-04 20:51:36.284584960     NaN
# min              NaN         NaN            2014-01-01 00:00:00     NaN
# 25%              NaN         NaN            2016-01-07 00:00:00     NaN
# 50%              NaN         NaN            2019-01-04 00:00:00     NaN
# 75%              NaN         NaN            2022-01-01 00:00:00     NaN
# max              NaN         NaN            2024-01-10 00:00:00     NaN
# std              NaN         NaN                            NaN     NaN
#
#          FailureUnit         Zone ZoneCategory Location Capital     Region  \
# count    5060.000000  5060.000000         5060     5060    5060       5060
# unique           NaN          NaN            4      115     108         15
# top              NaN          NaN          Low   Ariège   Paris  Occitanie
# freq             NaN          NaN         1291       44     132        616
# mean      323.962451     2.484783          NaN      NaN     NaN        NaN
# min         0.000000     1.000000          NaN      NaN     NaN        NaN
# 25%        45.000000     1.000000          NaN      NaN     NaN        NaN
# 50%        97.000000     2.000000          NaN      NaN     NaN        NaN
# 75%       221.000000     3.000000          NaN      NaN     NaN        NaN
# max     18612.000000     4.000000          NaN      NaN     NaN        NaN
# std      1248.369443     1.120160          NaN      NaN     NaN        NaN
#
#         Direction LocationCategory  CalandarYear
# count        5060             5060   5060.000000
# unique         11                5           NaN
# top     SouthEast                D           NaN
# freq          836             4180           NaN
# mean          NaN              NaN   2018.998024
# min           NaN              NaN   2014.000000
# 25%           NaN              NaN   2016.000000
# 50%           NaN              NaN   2019.000000
# 75%           NaN              NaN   2022.000000
# max           NaN              NaN   2024.000000
# std           NaN              NaN      3.162590

# %%
len(df['YearQuarterId'].unique())
# Out:
# 44

# %%
df['YearGroupId'].value_counts()
# Out:
# YearGroupId
# G2018    460
# G2019    460
# G2020    460
# G2021    460
# G2022    460
# G2023    460
# G2024    460
# G2014    460
# G2015    460
# G2016    460
# G2017    460
# Name: count, dtype: int64

# %%
df['ZoneCategory'].value_counts()
# Out:
# ZoneCategory
# Low         1291
# Medium      1276
# VeryHigh    1251
# High        1242
# Name: count, dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Location
# Ariège              44
# Val-d'Oise          44
# Tarn-et-Garonne     44
# Tarn                44
# Somme               44
#                     ..
# Cantal              44
# Calvados            44
# Bouches-du-Rhône    44
# Bas-Rhin            44
# Overseas            44
# Name: count, Length: 115, dtype: int64

# %%
df['Capital'].value_counts()
# Out:
# Capital
# Paris          132
# Nil             88
# Strasbourg      88
# Marseille       88
# Toulouse        88
#               ...
# Caen            44
# Rodez           44
# Carcassonne     44
# Troyes          44
# Basse-Terre     44
# Name: count, Length: 108, dtype: int64

# %%
df['Region'].value_counts(normalize=True,ascending=True)
# Out:
# Region
# Bourgogne-Frenche-Comté      0.008696
# Corse                        0.026087
# Bretagne                     0.043478
# Centre-ValdeLoire            0.052174
# PaysdelaLoire                0.052174
# Hauts-de-France              0.052174
# Normandie                    0.052174
# Provence-Alpes-Côted'Azur    0.060870
# Nil                          0.060870
# Bourgogne-Franche-Comté      0.078261
# Île-de-France                0.078261
# GrandEst                     0.095652
# Auvergne-Rhône-Alpes         0.104348
# Nouvelle-Aquitaine           0.113043
# Occitanie                    0.121739
# Name: proportion, dtype: float64

# %%
df['Direction'].value_counts(ascending=True)
# Out:
# Direction
# NorthWest       220
# Central         264
# West            308
# Nil             308
# East            396
# NorthCentral    396
# NorthEast       484
# North           528
# SouthWest       572
# South           748
# SouthEast       836
# Name: count, dtype: int64

# %%
df['LocationCategory'].value_counts(normalize=True)
# Out:
# LocationCategory
# D       0.826087
# R       0.113043
# C       0.043478
# OFOT    0.008696
# O       0.008696
# Name: proportion, dtype: float64

# %%
df['CalandarYear'].value_counts(dropna=False)
# Out:
# CalandarYear
# 2014    461
# 2018    460
# 2019    460
# 2020    460
# 2021    460
# 2022    460
# 2023    460
# 2015    460
# 2016    460
# 2017    460
# 2024    459
# Name: count, dtype: int64

# %%
df['Zone'].value_counts(bins=5)
# Out:
# (0.996, 1.6]    1291
# (1.6, 2.2]      1276
# (3.4, 4.0]      1251
# (2.8, 3.4]      1242
# (2.2, 2.8]         0
# Name: count, dtype: int64

# %%
df['FailureUnit'].value_counts(bins=10)
# Out:
# (-18.613, 1861.2]     4968
# (1861.2, 3722.4]        47
# (13028.4, 14889.6]      13
# (14889.6, 16750.8]       9
# (9306.0, 11167.2]        5
# (11167.2, 13028.4]       5
# (5583.6, 7444.8]         4
# (3722.4, 5583.6]         3
# (7444.8, 9306.0]         3
# (16750.8, 18612.0]       3
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# YearQuarterId       0
# YearGroupId         0
# Year                0
# Quarter             0
# FailureUnit         0
# Zone                0
# ZoneCategory        0
# Location            0
# Capital             0
# Region              0
# Direction           0
# LocationCategory    0
# CalandarYear        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Exploratory Analysis:

# %% [markdown]
# Univariate Analysis (Categorical and Numeric):

# %%
direction_counts = df['Direction'].value_counts()

# %%
direction_counts.plot(kind='bar', color='skyblue', figsize=(8, 5))
plt.title('Frequency of Directions', fontsize=16)
plt.xlabel('Direction', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=50)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
locationcategory_counts = df['LocationCategory'].value_counts()

# %%
fig, ax = plt.subplots(figsize=(8,7))
wedges, texts, autotexts = ax.pie(
    locationcategory_counts, 
    labels=None,  # Suppress labels on the pie itself
    autopct='%1.1f%%', 
    startangle=90, 
    colors=plt.cm.Pastel1.colors, 
    textprops={'fontsize': 8}
)
ax.legend(
    locationcategory_counts.index,  # Use the categories as labels
    title="Directions",  # Legend title
    loc="best",  # Position the legend automatically
    fontsize=8
)
# explode = [0.1] * len(locationcategory_counts)  # Explode all segments slightly
# ax.pie(locationcategory_counts, explode=explode,startangle=90)


plt.title('Location Proportions with Legend', fontsize=16)
plt.show()

# %%
plt.title('Pie Chart for Regions')
df['Region'].value_counts().plot(kind = "pie", autopct = "%5.1f%%")
plt.figure(figsize=(5,5))

# %%
sns.histplot(df['FailureUnit'], kde=True)
plt.title('Histogram of FailureUnit', fontsize=16)
plt.xlabel('FailureUnit', fontsize=14)
plt.ylabel('Count', fontsize=14)
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.kdeplot(df['FailureUnit'])
# Out:
# <Axes: xlabel='FailureUnit', ylabel='Density'>

# %%
sns.displot(df['FailureUnit'])

# %%
df.columns
# Out:
# Index(['YearQuarterId', 'YearGroupId', 'Year', 'Quarter', 'FailureUnit',
#        'Zone', 'ZoneCategory', 'Location', 'Capital', 'Region', 'Direction',
#        'LocationCategory', 'CalandarYear'],
#       dtype='object')

# %%
capital_counts = df['Capital'].value_counts().nlargest(5)

# %%
colors = ['red', 'blue', 'green', 'purple', 'orange']
capital_counts.plot(kind='bar', color=colors, figsize=(5, 5))
plt.title('Frequency of Capitals', fontsize=16)
plt.xlabel('Capital', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=50)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
location_counts = df['Location'].value_counts().nlargest(5)

# %%
plt.title('Pie Chart for Regions')
location_counts.plot(kind = "pie", autopct = "%5.1f%%")
plt.figure(figsize=(5,5))

# %%
quarter_dist = df['Quarter'].value_counts().nlargest(2)

# %%
colors = ['red', 'blue'] 
quarter_dist.plot(kind='bar', color=colors, figsize=(5, 5))
plt.title('Frequency of quarters', fontsize=16)
plt.xlabel('quarters', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=50)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df['ZoneCategory'].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='ZoneCategory'>

# %%
sns.boxplot(df['FailureUnit'])
# Out:
# <Axes: ylabel='FailureUnit'>

# %%
df['FailureUnit'].nlargest(10)
# Out:
# 1030    18612
# 798     17668
# 917     17297
# 1144    16674
# 4478    16526
# 2064    16366
# 4828    16022
# 4713    15939
# 1262    15839
# 2181    15624
# Name: FailureUnit, dtype: int64
